# %%
import sys
import os

# 현재 파일 위치 기준으로 최상위 루트 디렉토리(2단계 상위)를 sys.path에 추가
sys.path.append(os.path.abspath(os.path.join("..", "..")))

# 기존 임포트 코드
from course_utils.paths import (
    get_project_root,
    get_data_dir,
    get_report_dir,
)


PROJECT_ROOT = get_project_root()
DATA_DIR = get_data_dir()
REPORT_DIR = get_report_dir()

print("프로젝트 루트:", PROJECT_ROOT)
print("데이터 폴더:", DATA_DIR)
print("결과 폴더:", REPORT_DIR)
# Out:
# 프로젝트 루트: C:\Dev\llm-data-analysis
# 데이터 폴더: C:\Dev\llm-data-analysis\data\raw
# 결과 폴더: C:\Dev\llm-data-analysis\reports
