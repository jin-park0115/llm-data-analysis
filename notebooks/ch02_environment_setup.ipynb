# %% [markdown]
# ## 첫 환경 점검 셀

# %%
from pathlib import Path
import sys
print('Python 실행 파일:', sys.executable)
print('현재 작업 폴더:', Path.cwd())
# Out:
# Python 실행 파일: c:\Dev\llm-data-analysis\.venv\Scripts\python.exe
# 현재 작업 폴더: c:\Dev\llm-data-analysis\notebooks

# %% [markdown]
# ## customers.csv 읽어보기

# %%
print('현재 작업 폴더:', Path.cwd())
print('data/raw 존재 확인',Path('../data/raw').exists())
print('customers.csv 존재:', Path('../data/raw/customers.csv').exists())
# Out:
# 현재 작업 폴더: c:\Dev\llm-data-analysis\notebooks
# data/raw 존재 확인 True
# customers.csv 존재: True

# %% [markdown]
# Pandas로 읽기

# %%
import pandas as pd
df = pd.read_csv('../data/raw/customers.csv')
print('행, 열:', df.shape )
# Out:
# 행, 열: (150, 6)

# %%
# head()로 확인

df.head()
# Out:
#    customer_id name gender  age city signup_date
# 0            1  김수민      F   19   광주  2024-08-14
# 1            2  김정호      F   32   대구  2025-12-28
# 2            3  이경수      F   61   성남  2024-08-07
# 3            4  조영호      F   55   울산  2026-06-08
# 4            5  이예원      F   19   부산  2024-11-08
